# %%
from data_pipeline.rplan_content_extraction.rplan_content_extractor import parse_pdf_dir
import pandas as pd

# %%
parse_pdf_dir()
# Out:
# 2023-09-18 17:31:18.467 | INFO     | data_pipeline.pdf_scraper.tika_pdf_scraper:pdf_parser_from_folder:64 - Parsing file: arnsberg-2001-bochum_hagen.pdf
# 2023-09-18 17:31:19,694 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2023-09-18 17:31:29.179 | INFO     | data_pipeline.pdf_scraper.tika_pdf_scraper:pdf_parser_from_folder:64 - Parsing file: arnsberg-2004-dortmund_unna_hamm.pdf
# 2023-09-18 17:31:32.381 | INFO     | data_pipeline.pdf_scraper.tika_pdf_scraper:pdf_parser_from_folder:64 - Parsing file: arnsberg-2008-siegen.pdf
# 2023-09-18 17:31:33.768 | INFO     | data_pipeline.pdf_scraper.tika_pdf_scraper:pdf_parser_from_folder:64 - Parsing file: arnsberg-2012-kreis_soest_hochsauerlandkreis.pdf
# 2023-09-18 17:31:35.336 | INFO     | data_pipeline.pdf_scraper.tika_pdf_scraper:pdf_parser_from_folder:64 - Parsing file: bielefeld-_.pdf
# ...

# %%
pd.read_json("../data/NRW/extracted_rplan_content.json")
# Out:
#                         filename  \
# 0     arnsberg-2001-bochum_hagen
# 1     arnsberg-2001-bochum_hagen
# 2     arnsberg-2001-bochum_hagen
# 3     arnsberg-2001-bochum_hagen
# 4     arnsberg-2001-bochum_hagen
# ...                          ...
# 1696                   ruhr-2021
# 1697                   ruhr-2021
# 1698                   ruhr-2021
# 1699                   ruhr-2021
# 1700                   ruhr-2021
#
#                                                 chapter  \
# 0                                   freiraumentwicklung
# 1                                              freiraum
# 2                                    freiraumfunktionen
# 3     regionales ordnungskonzept und stärkung der in...
# 4                                              freiraum
# ...                                                 ...
# 1696                                                 ha
# 1697                                                 ha
# ...
