# %%
from visualizations.missing_data_analysis import visualizations_tables_NA_analysis

# %%
visualizations_tables_NA_analysis.histogram_BP_date()

# %%
visualizations_tables_NA_analysis.get_count_BP_downloaded()
# Out:
# download_status
# downloaded    0.803187
# error         0.196813
# Name: proportion, dtype: float64

# %%
print('Proportion of BP downloaded')
visualizations_tables_NA_analysis.get_count_BP_downloaded()
print('\n')
print('Total count of downloaded BP')
visualizations_tables_NA_analysis.get_count_BP_downloaded(normalized = False)
# Out:
# Proportion of BP downloaded
# download_status
# downloaded    0.803187
# error         0.196813
# Name: proportion, dtype: float64
#
#
# Total count of downloaded BP
# download_status
# downloaded    5342
# error         1309
# Name: count, dtype: int64

# %%
visualizations_tables_NA_analysis.plot_BP_downloads()

# %%
visualizations_tables_NA_analysis.plot_BP_downloads_year()
